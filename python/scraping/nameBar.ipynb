# %%
from pyecharts.engine import create_default_environment
from pyecharts import Page
from pyecharts import Bar, Line, Grid
from pyecharts import Liquid

import xlrd

# %%
#fileName = r'/home/liang.liang/code/Tools/python/scraping/name2019.5.15.xlsx'
fileName = r'/Users/lc/code/Tools/python/scraping/beijing_done_201806_201906_release.xlsx'

data = xlrd.open_workbook(fileName)

table = data.sheets()[0]


Source =  {"name":table.col_values(1,1)}

Total = len(Source["name"])

nameList = {}

# %%
for i in range(Total):
    name = Source["name"][i]
    if(name in nameList):
        if(name == "流拍"):
            pass
        else:
            nameList[name] +=1
    else:
        nameList[name] = 1

# %%
keys = list(nameList.keys())
values = list(nameList.values())

# %%
newNameList = {}

# %%
for name in keys:
    if ( nameList[name] > 1 ):
        newNameList[name] = nameList[name]

# %%
newKeys = list(newNameList.keys())
newValues = list(newNameList.values())
print(newKeys)
print(newValues)
# Out:
# ['百科荣创（北京）科技发展有限公司', '鞠芳', '王力', '王宝义', '王敏', '申智灵', '霍建平', '姚海凤', '东晟日鑫（北京）酒店管理有限公司', '王峰', '苏州卓宝防水工程有限公司', '刘琦', '王海滨', '西安康泰兴业置业有限公司', '赵小梅', '田春俊', '刘超', '茌平万泽商贸有限公司', '王辉', '陈龙', '陈敏', '徐州重型机械有限公司', '杨书芳', '何鹏', '绍兴柳荷贸易有限公司', '张宇霄', '刘洋', '北京春雪羊绒有限公司']
# [2, 2, 3, 3, 2, 2, 3, 2, 6, 2, 2, 3, 3, 3, 2, 3, 4, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]

# %%
number = len(newKeys)
print(number)
# Out:
# 28

# %%
bar = Bar(title="beijing",subtitle ="2018.6_2019.6",width = number*60, height = number*30 )
#bar = Bar(title="Name ",subtitle ="2018.1_2019.5")

# %%
bar.add(0, newKeys, newValues
            ,xaxis_rotate=0,yaxis_rotate=0,xaxis_interval= 0
            ,is_label_show=False,yaxis_pos = "left"
            ,xaxis_type = 'category',is_stack = True,is_convert = True,yaxis_label_textsize = 12
            ,yaxis_name_gap = 5
            ,is_toolbox_show = True,is_more_utils=True
            ,yaxis_interval = 0,yaxis_margin= 0
            ,legend_pos="30%"
           )
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="5d7b67fa4a2549e6abb3e8f7494e88a3" style="width:1680px;height:840px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_5d7b67fa4a2549e6abb3e8f7494e88a3 = echarts.init(document.getElementById('5d7b67fa4a2549e6abb3e8f7494e88a3'), 'light', {renderer: 'canvas'});
#
# var option_5d7b67fa4a2549e6abb3e8f7494e88a3 = {
#     "title": [
#         {
#             "text": "beijing",
#             "subtext": "2018.6_2019.6",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             },
#             "magicType": {
#                 "show": true,
#                 "type": [
#                     "line",
#                     "bar",
#                     "stack",
#                     "tiled"
#                 ],
#                 "title": {
#                     "line": "\u6298\u7ebf\u56fe",
#                     "bar": "\u67f1\u72b6\u56fe",
#                     "stack": "\u5806\u53e0",
#                     "tiled": "\u5e73\u94fa"
#                 }
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "zoom": "\u533a\u57df\u7f29\u653e",
#                     "back": "\u7f29\u653e\u8fd8\u539f"
#                 }
#             }
#         }
#     },
#     "series_id": 4751643,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": 0,
#             "data": [
#                 2,
#                 2,
#                 3,
#                 3,
#                 2,
#                 2,
#                 3,
#                 2,
#                 6,
#                 2,
#                 2,
#                 3,
#                 3,
#                 3,
#                 2,
#                 3,
#                 4,
#                 2,
#                 2,
#                 2,
#                 2,
#                 2,
#                 2,
#                 2,
#                 2,
#                 2,
#                 2,
#                 2
#             ],
#             "stack": "stack_4751643",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 4751643
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 0
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "30%",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": 0,
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 5,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": "left",
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": 0,
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u767e\u79d1\u8363\u521b\uff08\u5317\u4eac\uff09\u79d1\u6280\u53d1\u5c55\u6709\u9650\u516c\u53f8",
#                 "\u97a0\u82b3",
#                 "\u738b\u529b",
#                 "\u738b\u5b9d\u4e49",
#                 "\u738b\u654f",
#                 "\u7533\u667a\u7075",
#                 "\u970d\u5efa\u5e73",
#                 "\u59da\u6d77\u51e4",
#                 "\u4e1c\u665f\u65e5\u946b\uff08\u5317\u4eac\uff09\u9152\u5e97\u7ba1\u7406\u6709\u9650\u516c\u53f8",
#                 "\u738b\u5cf0",
#                 "\u82cf\u5dde\u5353\u5b9d\u9632\u6c34\u5de5\u7a0b\u6709\u9650\u516c\u53f8",
#                 "\u5218\u7426",
#                 "\u738b\u6d77\u6ee8",
#                 "\u897f\u5b89\u5eb7\u6cf0\u5174\u4e1a\u7f6e\u4e1a\u6709\u9650\u516c\u53f8",
#                 "\u8d75\u5c0f\u6885",
#                 "\u7530\u6625\u4fca",
#                 "\u5218\u8d85",
#                 "\u830c\u5e73\u4e07\u6cfd\u5546\u8d38\u6709\u9650\u516c\u53f8",
#                 "\u738b\u8f89",
#                 "\u9648\u9f99",
#                 "\u9648\u654f",
#                 "\u5f90\u5dde\u91cd\u578b\u673a\u68b0\u6709\u9650\u516c\u53f8",
#                 "\u6768\u4e66\u82b3",
#                 "\u4f55\u9e4f",
#                 "\u7ecd\u5174\u67f3\u8377\u8d38\u6613\u6709\u9650\u516c\u53f8",
#                 "\u5f20\u5b87\u9704",
#                 "\u5218\u6d0b",
#                 "\u5317\u4eac\u6625\u96ea\u7f8a\u7ed2\u6709\u9650\u516c\u53f8"
#             ]
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_5d7b67fa4a2549e6abb3e8f7494e88a3.setOption(option_5d7b67fa4a2549e6abb3e8f7494e88a3);
#
#     });
# </script>

# %%
bar.render("beijing_201806_201906.html")

# %%
   ''' 
    def CWStatus(self):
        barCW = Bar(title="Feature Status", title_text_size = 20
          ,subtitle ="Total items:" +str(self.__featureLen)
          ,width = self.__autowidth)

        for i in self.__status:
            barCW.add(i, self.__cw, list(self.__status_cw[i].values())
            ,xaxis_rotate=0,yaxis_rotate=0,xaxis_interval= 0
            ,is_label_show=False,yaxis_pos = "left"
            ,xaxis_type = 'category',is_stack = True,is_convert = True,yaxis_label_textsize = 12
            ,yaxis_name_gap = 5
            ,is_toolbox_show = True,is_more_utils=True
            ,yaxis_interval = 0,yaxis_margin= 0
            ,legend_pos="30%"
           )
        
        return barCW
    '''
# Out:
# ' \n def CWStatus(self):\n     barCW = Bar(title="Feature Status", title_text_size = 20\n       ,subtitle ="Total items:" +str(self.__featureLen)\n       ,width = self.__autowidth)\n\n     for i in self.__status:\n         barCW.add(i, self.__cw, list(self.__status_cw[i].values())\n         ,xaxis_rotate=0,yaxis_rotate=0,xaxis_interval= 0\n         ,is_label_show=False,yaxis_pos = "left"\n         ,xaxis_type = \'category\',is_stack = True,is_convert = True,yaxis_label_textsize = 12\n         ,yaxis_name_gap = 5\n         ,is_toolbox_show = True,is_more_utils=True\n         ,yaxis_interval = 0,yaxis_margin= 0\n         ,legend_pos="30%"\n        )\n     \n     return barCW\n '

# %%
# import csv
# import pandas as pd


# csv = pd.read_csv('namelist.csv', encoding='utf-8')
# csv.to_excel('tianjin2017_2018.xlsx', sheet_name='data')
