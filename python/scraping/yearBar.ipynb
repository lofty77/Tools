# %%
from pyecharts import options as opts
from pyecharts.charts  import Page,Bar,Line,Grid
from pyecharts.charts import Liquid
from pyecharts.charts import Geo
from pyecharts.globals import ChartType, SymbolType
from pyecharts.charts import Map

from example.commons import Faker


import xlrd

# %%
fileName = r'/home/liang.liang/code/Tools/python/scraping/tianjin_full.xlsx'
#fileName = r'/Users/lc/code/Tools/python/scraping/tianjin_full.xlsx'

data = xlrd.open_workbook(fileName)

table = data.sheets()[0]


Source =  {"name":table.col_values(1,1),"year":table.col_values(2,1)}

# %%
year_list = list(set(Source["year"]))
year_list.remove(2014.0)
year_list.sort()
year_list
# Out:
# [2015.0, 2016.0, 2017.0, 2018.0, 2019.0]

# %%
# year_count_all = []
# for y in year_list:
#     year_count_all.append(Source["year"].count(y))

# year_count_all

# %%
year_count_sucess = []
year_count_fail = []


for y in year_list:
    count_sucess = 0
    count_fail = 0
    for i in range(len(Source["name"])):
        if Source["name"][i] != "流拍" and Source["year"][i] == y :
            count_sucess +=1
        elif Source["name"][i] == "流拍" and Source["year"][i] == y :
            count_fail +=1
        else:
            pass

    year_count_sucess.append(count_sucess)
    year_count_fail.append(count_fail)


year_count_sucess
# Out:
# [107, 454, 629, 653, 455]

# %%
year_count_fail
# Out:
# [504, 1055, 1110, 1394, 914]

# %%
year_sucess = dict(zip(year_list,year_count_sucess))
year_sucess
# Out:
# {2015.0: 107, 2016.0: 454, 2017.0: 629, 2018.0: 653, 2019.0: 455}

# %%
year_fail = dict(zip(year_list,year_count_fail))
year_fail
# Out:
# {2015.0: 504, 2016.0: 1055, 2017.0: 1110, 2018.0: 1394, 2019.0: 914}

# %%
bar = Bar()


bar.add_xaxis(year_list)
bar.add_yaxis("成交",year_count_sucess)
bar.add_yaxis("流拍",year_count_fail)

bar.set_series_opts(label_opts=opts.LabelOpts(is_show=True))

bar.set_global_opts(title_opts=opts.TitleOpts(title="TianJin 2014-2019"),
                     xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=0)),
                     yaxis_opts=opts.AxisOpts
                            (axislabel_opts=opts.LabelOpts(rotate=0),
                             is_inverse = False,
                             name_location = "end",
                             min_interval = 1,
                             splitline_opts=opts.SplitLineOpts(is_show=True)
                             ),
                     toolbox_opts=opts.ToolboxOpts(orient="vertical",pos_left = "90%")
                   )

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="1f5406444cac457abd4445941306ed8b" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_1f5406444cac457abd4445941306ed8b = echarts.init(
#             document.getElementById('1f5406444cac457abd4445941306ed8b'), 'white', {renderer: 'canvas'});
#         var option_1f5406444cac457abd4445941306ed8b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u6210\u4ea4",
#             "data": [
#                 107,
#                 454,
#                 629,
#                 653,
#                 455
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u6d41\u62cd",
#             "data": [
#                 504,
#                 1055,
#                 1110,
#                 1394,
#                 914
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6210\u4ea4",
#                 "\u6d41\u62cd"
#             ],
#             "selected": {
#                 "\u6210\u4ea4": true,
#                 "\u6d41\u62cd": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": 0,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 2015.0,
#                 2016.0,
#                 2017.0,
#                 2018.0,
#                 2019.0
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": 0,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 1,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "TianJin 2014-2019"
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "itemSize": 15,
#         "itemGap": 10,
#         "left": "90%",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image",
#                 "type": "png"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view",
#                 "readOnly": false
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "zoom": "data zoom",
#                     "back": "data zoom restore"
#                 }
#             }
#         }
#     }
# };
#         chart_1f5406444cac457abd4445941306ed8b.setOption(option_1f5406444cac457abd4445941306ed8b);
#     });
# </script>

# %%
def geo_guangdong() -> Geo:
    c = (
        Geo()
        .add_schema(maptype="天津")
        .add(
            "geo",
            [],
            type_=ChartType.HEATMAP,
        )
        .set_series_opts(label_opts=opts.LabelOpts(is_show=True))
        .set_global_opts(
            visualmap_opts=opts.VisualMapOpts(),
            title_opts=opts.TitleOpts(title="Geo-天津地图"),
        )
    )
    return c

show = geo_guangdong()
show.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '天津':'https://assets.pyecharts.org/assets/maps/tianjin'
#         }
#     });
# </script>
#
#     <div id="3bc7f6c9404f48cba43214cd0d1ca6e7" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', '天津'], function(echarts) {
#         var chart_3bc7f6c9404f48cba43214cd0d1ca6e7 = echarts.init(
#             document.getElementById('3bc7f6c9404f48cba43214cd0d1ca6e7'), 'white', {renderer: 'canvas'});
#         var option_3bc7f6c9404f48cba43214cd0d1ca6e7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "name": "geo",
#             "coordinateSystem": "geo",
#             "data": [],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "geo"
#             ],
#             "selected": {
#                 "geo": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Geo-\u5929\u6d25\u5730\u56fe"
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true
#     },
#     "geo": {
#         "map": "\u5929\u6d25",
#         "roam": true,
#         "emphasis": {}
#     }
# };
#         chart_3bc7f6c9404f48cba43214cd0d1ca6e7.setOption(option_3bc7f6c9404f48cba43214cd0d1ca6e7);
#     });
# </script>
